# %%
import pandas as pd
import numpy as np
import json
import ast

# %%
# %cd C:\\Users\\Familia Lara Pernia\\Desktop\\Henry\\Proyectos Individuales\\archivos del proyecto 1_Steam_games
# %pwd
# Out:
# C:\Users\Familia Lara Pernia\Desktop\Henry\Proyectos Individuales\archivos del proyecto 1_Steam_games
# 'C:\\Users\\Familia Lara Pernia\\Desktop\\Henry\\Proyectos Individuales\\archivos del proyecto 1_Steam_games'

# %%
#Lista para guardar cada fila
lista_aux=[]
with open("australian_user_reviews.json",encoding="utf-8") as file:
    for line in file.readlines():
        lista_aux.append(ast.literal_eval(line))

# %%
#Tomo la lista y creo un data frame a partir de ella:
df_reviews=pd.DataFrame(lista_aux)

# %%
#Observamos que informacion trae nuestro archivo
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
#Verificamos sus columnas y si posee nulos:
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25799 entries, 0 to 25798
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25799 non-null  object
#  1   user_url  25799 non-null  object
#  2   reviews   25799 non-null  object
# dtypes: object(3)
# memory usage: 604.8+ KB

# %% [markdown]
# VERIFICAMOS SI POSEE DUPLICADOS Y LUEGO PROCEDEREMOS A BORRAR LOS MISMOS

# %%
#verificamos los duplicados por medio de la columna "user_id"
duplicados= df_reviews[df_reviews.duplicated(subset=['user_id'])]
duplicados
# Out:
#                  user_id                                           user_url  \
# 456           bokkkbokkk            http://steamcommunity.com/id/bokkkbokkk
# 1182          ImSeriouss            http://steamcommunity.com/id/ImSeriouss
# 1456   76561198062039159  http://steamcommunity.com/profiles/76561198062...
# 1477   76561198045009232  http://steamcommunity.com/profiles/76561198045...
# 1746        nitr0ticwolf          http://steamcommunity.com/id/nitr0ticwolf
# ...                  ...                                                ...
# 17819  76561198076474887  http://steamcommunity.com/profiles/76561198076...
# 17916        yolofaceguy           http://steamcommunity.com/id/yolofaceguy
# 18028  76561198075591109  http://steamcommunity.com/profiles/76561198075...
# 18234  76561198092022514  http://steamcommunity.com/profiles/76561198092...
# 18309     SuchGayMuchWow        http://steamcommunity.com/id/SuchGayMuchWow
#
#                                                  reviews
# ...

# %%
#Se borran los duplicados por medio de la columna"user_id"
df_reviews_sin_duplicados = df_reviews.drop_duplicates(subset=['user_id'])
df_reviews_sin_duplicados
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %% [markdown]
# COMENZAREMOS A TRABAJAR CON LA COLUMNA "REVIEWS" YA QUE ES DE MUCHO INTERES EN NUESTRO PROYECTO

# %% [markdown]
# La columna 'reviews' se presenta anidada, siendo una lista con uno o mas diccionarios como elementos. Se busca generar una columna por cada diccionario para posteriormente hacer un registro por cada diccionario.

# %%
# Se transforma a columnas cada elemento de las listas
df_reviews2 = pd.json_normalize(df_reviews['reviews'])
df_reviews2.head()
# Out:
#                                                    0  \
# 0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1  {'funny': '', 'posted': 'Posted June 24, 2014....
# 2  {'funny': '', 'posted': 'Posted February 3.', ...
# 3  {'funny': '', 'posted': 'Posted October 14, 20...
# 4  {'funny': '3 people found this review funny', ...
#
#                                                    1  \
# 0  {'funny': '', 'posted': 'Posted July 15, 2011....
# 1  {'funny': '', 'posted': 'Posted September 8, 2...
# 2  {'funny': '', 'posted': 'Posted December 4, 20...
# 3  {'funny': '', 'posted': 'Posted July 28, 2012....
# 4  {'funny': '1 person found this review funny', ...
#
#                                                    2  \
# 0  {'funny': '', 'posted': 'Posted April 21, 2011...
# 1  {'funny': '', 'posted': 'Posted November 29, 2...
# 2  {'funny': '', 'posted': 'Posted November 3, 20...
# 3  {'funny': '', 'posted': 'Posted June 2, 2012.'...
# ...

# %% [markdown]
# En esta transformación, se pierde el 'user_id' y 'user_url' al que pertenece cada diccionario, pero aún mantiene la misma posición. Para volver a tener la trazabilidad del usuario, se concatena con el dataframe anterior.

# %%
# Se agrega el 'user_id' y 'user_url' a las columnas separadas 
df_reviews2 = pd.concat([df_reviews[['user_id', 'user_url']], df_reviews2], axis=1)
df_reviews2.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                                    0  \
# 0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1  {'funny': '', 'posted': 'Posted June 24, 2014....
# 2  {'funny': '', 'posted': 'Posted February 3.', ...
# 3  {'funny': '', 'posted': 'Posted October 14, 20...
# 4  {'funny': '3 people found this review funny', ...
#
#                                                    1  \
# 0  {'funny': '', 'posted': 'Posted July 15, 2011....
# 1  {'funny': '', 'posted': 'Posted September 8, 2...
# ...

# %% [markdown]
# Ahora que se tienen los diccionarios por columnas, con el usuario que genera dicha información, se genera un registro por cada diccionario, manteniendo en cada caso el usuario que lo genera.

# %%
# Se utiliza pd.melt para transformar las columnas en filas conservando el 'user_id' y 'user_url'
df_reviews2 = pd.melt(df_reviews2, id_vars=['user_id', 'user_url'], 
                       value_vars=list(range(9)),
                       value_name='reviews')

# %%
df_reviews2.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#   variable                                            reviews
# 0        0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1        0  {'funny': '', 'posted': 'Posted June 24, 2014....
# 2        0  {'funny': '', 'posted': 'Posted February 3.', ...
# 3        0  {'funny': '', 'posted': 'Posted October 14, 20...
# 4        0  {'funny': '3 people found this review funny', ...

# %% [markdown]
# En el output anterior se noto que existian valores nulos para 'reviews'.
# Se eliminan los registros que tienen None en 'reviews'.

# %%
# Se eliminan las filas con valor None
df_reviews2 = df_reviews2.dropna()

# %% [markdown]
# En este punto ya es posible convertir cada diccionario en columna.

# %%
# Se separan por columnas cada una de las claves de 'reviews'
df_reviews = df_reviews2['reviews'].apply(pd.Series, dtype='object')
df_reviews = df_reviews.add_prefix('reviews_')
df_reviews.head()
# Out:
#                       reviews_funny            reviews_posted  \
# 0                                    Posted November 5, 2011.
# 1                                       Posted June 24, 2014.
# 2                                          Posted February 3.
# 3                                    Posted October 14, 2013.
# 4  3 people found this review funny    Posted April 15, 2014.
#
#   reviews_last_edited reviews_item_id  \
# 0                                1250
# 1                              251610
# 2                              248820
# 3                              250320
# 4                              211420
#
#                                    reviews_helpful  reviews_recommend  \
# 0                                   No ratings yet               True
# 1  15 of 20 people (75%) found this review helpful               True
# 2                                   No ratings yet               True
# 3   2 of 2 people (100%) found this review helpful               True
# ...

# %% [markdown]
# En el procesamiento anterior, se puede ver que la columna de 'user_id' y 'user_url' se perdió nuevamente, por lo que se vuelve a concatenar.

# %%
# Se une con el 'user_id' y 'user_url'
df_reviews = pd.concat([df_reviews2[['user_id', 'user_url']], df_reviews], axis=1)
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                       reviews_funny            reviews_posted  \
# 0                                    Posted November 5, 2011.
# 1                                       Posted June 24, 2014.
# 2                                          Posted February 3.
# 3                                    Posted October 14, 2013.
# 4  3 people found this review funny    Posted April 15, 2014.
#
#   reviews_last_edited reviews_item_id  \
# 0                                1250
# 1                              251610
# ...

# %% [markdown]
# Se observa que hay valores faltantes en algunas columnas, pero no estan como nulos, probablemente deben tener un espacio.
# Se reemplazara esos espacios como valores nulos

# %%
df_reviews.replace('', None, inplace=True)
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                       reviews_funny            reviews_posted  \
# 0                              None  Posted November 5, 2011.
# 1                              None     Posted June 24, 2014.
# 2                              None        Posted February 3.
# 3                              None  Posted October 14, 2013.
# 4  3 people found this review funny    Posted April 15, 2014.
#
#   reviews_last_edited reviews_item_id  \
# 0                None            1250
# 1                None          251610
# ...

# %% [markdown]
# Vamos a verificar como ha quedado nuestro df

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59036 entries, 0 to 232129
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              59036 non-null  object
#  1   user_url             59036 non-null  object
#  2   reviews_funny        8132 non-null   object
#  3   reviews_posted       59036 non-null  object
#  4   reviews_last_edited  6083 non-null   object
#  5   reviews_item_id      59036 non-null  object
#  6   reviews_helpful      59036 non-null  object
#  7   reviews_recommend    59036 non-null  bool
#  8   reviews_review       59006 non-null  object
# dtypes: bool(1), object(8)
# memory usage: 4.1+ MB

# %% [markdown]
# Observamos que para las columnas 'reviews_funny' y 'reviews_last_edited' tenemos una alta cantidad, por ello decidimos borrarlos ya que lo consideramos sin relevancia.

# %%
# Se eliminan las columnas 'reviews_funny' y 'reviews_last_edited'
df_reviews = df_reviews.drop(columns=['reviews_funny', 'reviews_last_edited'])
df_reviews.columns
# Out:
# Index(['user_id', 'user_url', 'reviews_posted', 'reviews_item_id',
#        'reviews_helpful', 'reviews_recommend', 'reviews_review'],
#       dtype='object')

# %% [markdown]
# * CARGO EL DATASEET LIMPIO

# %%
#Me ubico dentro de la carpeta archivos csv
# %cd C:\\Users\\Familia Lara Pernia\\Desktop\\Henry\\Proyectos Individuales\\Proyecto1_Steam_Games\\archivos csv
# %pwd
# Out:
# C:\Users\Familia Lara Pernia\Desktop\Henry\Proyectos Individuales\Proyecto1_Steam_Games\archivos csv
# 'C:\\Users\\Familia Lara Pernia\\Desktop\\Henry\\Proyectos Individuales\\Proyecto1_Steam_Games\\archivos csv'

# %%
archivo_limpio = 'user_reviews_limpio.csv'
df_reviews.to_csv(archivo_limpio, index=False, encoding='utf-8')
